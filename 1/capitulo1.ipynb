# %% [markdown]
# ### Esse capítulo é uma introdução ao web scrapping. Teremos:
# 1. Introdução ao HTML
# 2. Coleta através de strings HTML

# %% [markdown]
# ### No código de HTML existe um componente chamado de tags, onde o HTML guarda suas informações. Existem vários tipos de tags
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Existe uma hierarquia no código HTML onde os dados são inseridos. Por exemplo:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Normalmente, no código HTML teremos atributos com um nome específico e um valor específico onde podemos selecionar posteriormente:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Para percorrer o caminho dos dados devemos usar / para avançar uma geração e podemos usar [] para especificar qual elemento escolher
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Para selecionar todos os elementos posteriores(que podem estar bem depois de uma geração) usamos o //:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Resumo:
# ![image.png](attachment:image.png)
